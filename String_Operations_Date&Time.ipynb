# %% [markdown]
# <a href="https://colab.research.google.com/github/Guru1378/Python-libraries/blob/main/String_Operations_Date%26Time.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
new_data=df.groupby(["sex","smoker"])[["total_bill"]].mean()
# Out:
# /tmp/ipython-input-9-3703137646.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   new_data=df.groupby(["sex","smoker"])[["total_bill"]].mean()

# %%
new_data
# Out:
#                total_bill
# sex    smoker
# Male   Yes      22.284500
#        No       19.791237
# Female Yes      17.977879
#        No       18.105185

# %%
new_data.unstack()
# Out:
#        total_bill
# smoker        Yes         No
# sex
# Male    22.284500  19.791237
# Female  17.977879  18.105185

# %%
data=df.pivot_table(index="sex",columns="smoker",values="total_bill")
# Out:
# /tmp/ipython-input-12-2339227293.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   data=df.pivot_table(index="sex",columns="smoker",values="total_bill")

# %%
data
# Out:
# smoker        Yes         No
# sex
# Male    22.284500  19.791237
# Female  17.977879  18.105185

# %%
data=df.pivot_table(index="sex",columns="smoker",values="total_bill",aggfunc="sum")
# Out:
# /tmp/ipython-input-15-3889917411.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   data=df.pivot_table(index="sex",columns="smoker",values="total_bill",aggfunc="sum")

# %%
data
# Out:
# smoker      Yes       No
# sex
# Male    1337.07  1919.75
# Female   593.27   977.68

# %%
data1=df.pivot_table(index="sex",columns="smoker",values="total_bill",aggfunc="count")
# Out:
# /tmp/ipython-input-17-287271125.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   data1=df.pivot_table(index="sex",columns="smoker",values="total_bill",aggfunc="count")

# %%
data1
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
data2=df.pivot_table(index="sex",columns="smoker",values="total_bill",aggfunc="max")
# Out:
# /tmp/ipython-input-19-2149850658.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   data2=df.pivot_table(index="sex",columns="smoker",values="total_bill",aggfunc="max")

# %%
data2
# Out:
# smoker    Yes     No
# sex
# Male    50.81  48.33
# Female  44.30  35.83

# %%
data3=df.pivot_table(index="sex",columns="smoker",values="total_bill",aggfunc="min")
# Out:
# /tmp/ipython-input-23-2595419193.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   data3=df.pivot_table(index="sex",columns="smoker",values="total_bill",aggfunc="min")

# %%
data3
# Out:
# smoker   Yes    No
# sex
# Male    7.25  7.51
# Female  3.07  7.25

# %%
data4=df.pivot_table(index="sex",columns="smoker",values="total_bill",aggfunc="median")
# Out:
# /tmp/ipython-input-25-80843693.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   data4=df.pivot_table(index="sex",columns="smoker",values="total_bill",aggfunc="median")

# %%
data4
# Out:
# smoker    Yes     No
# sex
# Male    20.39  18.24
# Female  16.27  16.69

# %%
data5=df.pivot_table(index=["sex","smoker"],columns=["day","time"],aggfunc={"total_bill":"mean","tip":"sum"})
# Out:
# /tmp/ipython-input-33-2266087920.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   data5=df.pivot_table(index=["sex","smoker"],columns=["day","time"],aggfunc={"total_bill":"mean","tip":"sum"})

# %%
data5
# Out:
#                  tip                                                  \
# day             Thur          Fri          Sat           Sun
# time           Lunch Dinner Lunch Dinner Lunch  Dinner Lunch  Dinner
# sex    smoker
# Male   Yes     30.58    0.0  5.70  16.23   0.0   77.74   0.0   52.82
#        No      58.83    0.0  0.00   5.00   0.0  104.21   0.0  133.96
# Female Yes     20.93    0.0  7.98  10.80   0.0   43.03   0.0   14.00
#        No      58.49    3.0  3.00   3.25   0.0   35.42   0.0   46.61
#
#               total_bill
# day                 Thur               Fri                Sat        Sun
# time               Lunch Dinner      Lunch  Dinner     Dinner     Dinner
# sex    smoker
# Male   Yes     19.171000    NaN  11.386667  25.892  21.837778  26.141333
#        No      18.486500    NaN        NaN  17.475  19.929063  20.403256
# Female Yes     19.218571    NaN  13.260000  12.200  20.266667  16.540000
# ...

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 4 entries, ('Male', 'Yes') to ('Female', 'No')
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   (tip, Thur, Lunch)          4 non-null      float64
#  1   (tip, Thur, Dinner)         4 non-null      float64
#  2   (tip, Fri, Lunch)           4 non-null      float64
#  3   (tip, Fri, Dinner)          4 non-null      float64
#  4   (tip, Sat, Lunch)           4 non-null      float64
#  5   (tip, Sat, Dinner)          4 non-null      float64
#  6   (tip, Sun, Lunch)           4 non-null      float64
#  7   (tip, Sun, Dinner)          4 non-null      float64
#  8   (total_bill, Thur, Lunch)   4 non-null      float64
#  9   (total_bill, Thur, Dinner)  1 non-null      float64
#  10  (total_bill, Fri, Lunch)    3 non-null      float64
#  11  (total_bill, Fri, Dinner)   4 non-null      float64
# ...
