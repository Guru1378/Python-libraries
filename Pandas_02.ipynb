# %% [markdown]
# <a href="https://colab.research.google.com/github/Guru1378/Python-libraries/blob/main/Pandas_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Creating DataFrame

# %%
student_data=[
    [100,100,100],
    [98,100,100],
    [100,100,100],
    [98,99,100],
    [100,100,100],

]

pd.DataFrame(student_data,columns=["Maths","Science","English"])
# Out:
#    Maths  Science  English
# 0    100      100      100
# 1     98      100      100
# 2    100      100      100
# 3     98       99      100
# 4    100      100      100

# %%
stdudent_dict={
    "Maths":[100,98,100,98,100],
    "Science":[100,100,100,90,90],
}
pd.DataFrame(stdudent_dict)
# Out:
#    Maths  Science
# 0    100      100
# 1     98      100
# 2    100      100
# 3     98       90
# 4    100       90

# %%
   movies=pd.read_csv("/content/TeluguMovies_dataset.csv")

# %%
movies
# Out:
#       Unnamed: 0                        Movie    Year Certificate  \
# 0              0      Bahubali: The Beginning  2015.0          UA
# 1              1  Baahubali 2: The Conclusion  2017.0          UA
# 2              2              1 - Nenokkadine  2014.0          UA
# 3              3                      Dhoom:3  2013.0          UA
# 4              4                       Ra.One  2011.0           U
# ...          ...                          ...     ...         ...
# 1395        1395                Maro Monagadu  1985.0         NaN
# 1396        1396                     Jakkanna  2016.0         NaN
# 1397        1397               Muvva Gopaludu  1987.0         NaN
# 1398        1398        Ninney Ishta Paddaanu  2003.0           U
# 1399        1399                     9 Nelalu  2001.0           U
#
#                                       Genre  \
# 0                 Action, Drama
# 1                 Action, Drama
# 2              Action, Thriller
# ...

# %%
movies.shape
# Out:
# (1400, 9)

# %%
movies.dtypes
# Out:
# Unnamed: 0         int64
# Movie             object
# Year             float64
# Certificate       object
# Genre             object
# Overview          object
# Runtime            int64
# Rating           float64
# No.of.Ratings      int64
# dtype: object

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1400, step=1)

# %%
movies.columns
# Out:
# Index(['Unnamed: 0', 'Movie', 'Year', 'Certificate', 'Genre', 'Overview',
#        'Runtime', 'Rating', 'No.of.Ratings'],
#       dtype='object')

# %%
movies[movies['Rating']>8]
# Out:
#       Unnamed: 0                               Movie    Year Certificate  \
# 0              0             Bahubali: The Beginning  2015.0          UA
# 1              1         Baahubali 2: The Conclusion  2017.0          UA
# 2              2                     1 - Nenokkadine  2014.0          UA
# 8              8                         Arjun Reddy  2017.0           A
# 9              9                        Rangasthalam  2018.0          UA
# ...          ...                                 ...     ...         ...
# 1375        1375                      Ugranarasimham  1986.0         NaN
# 1376        1376      Paramanandayya Shishyula Katha  1966.0           U
# 1383        1383  Screenplay of an Indian Love Story  2020.0           A
# 1384        1384                   Chal Mohana Ranga  1978.0         NaN
# 1395        1395                       Maro Monagadu  1985.0         NaN
#
#                                    Genre  \
# 0              Action, Drama
# ...

# %%
movies[movies['Rating']>8].size
# Out:
# 801

# %%
movies.values
# Out:
# array([[0, 'Bahubali: The Beginning', 2015.0, ..., 159, 8.1, 99114],
#        [1, 'Baahubali 2: The Conclusion', 2017.0, ..., 167, 8.2, 71458],
#        [2, '1 - Nenokkadine', 2014.0, ..., 170, 8.1, 42372],
#        ...,
#        [1397, 'Muvva Gopaludu', 1987.0, ..., 137, 7.8, 49],
#        [1398, 'Ninney Ishta Paddaanu', 2003.0, ..., 0, 5.9, 49],
#        [1399, '9 Nelalu', 2001.0, ..., 0, 7.3, 49]], dtype=object)

# %%
movies.head()
# Out:
#    Unnamed: 0                        Movie    Year Certificate  \
# 0           0      Bahubali: The Beginning  2015.0          UA
# 1           1  Baahubali 2: The Conclusion  2017.0          UA
# 2           2              1 - Nenokkadine  2014.0          UA
# 3           3                      Dhoom:3  2013.0          UA
# 4           4                       Ra.One  2011.0           U
#
#                                    Genre  \
# 0              Action, Drama
# 1              Action, Drama
# 2           Action, Thriller
# 3           Action, Thriller
# 4  Action, Adventure, Sci-Fi
#
#                                             Overview  Runtime  Rating  \
# 0      In ancient India, an adventurous and darin...      159     8.1
# 1      When Shiva, the son of Bahubali, learns ab...      167     8.2
# 2      A rock star must overcome his psychologica...      170     8.1
# 3      When Sahir, a circus entertainer trained i...      172     5.4
# ...

# %%
movies.tail()
# Out:
#       Unnamed: 0                  Movie    Year Certificate  \
# 1395        1395          Maro Monagadu  1985.0         NaN
# 1396        1396               Jakkanna  2016.0         NaN
# 1397        1397         Muvva Gopaludu  1987.0         NaN
# 1398        1398  Ninney Ishta Paddaanu  2003.0           U
# 1399        1399               9 Nelalu  2001.0           U
#
#                            Genre  \
# 1395                         NaN
# 1396   Comedy, Drama
# 1397  Drama, Romance
# 1398                         NaN
# 1399           Drama
#
#                                                Overview  Runtime  Rating  \
# 1395                                                NaN        0     8.6
# 1396      The movie is about an attempt by Sunil the...        0     6.3
# 1397      Muvva Gopaludu is a 1987 Indian Telugu fil...      137     7.8
# 1398      Hero Charan (Tarun) a middle class family ...        0     5.9
# ...

# %%
movies.sample()
# Out:
#    Unnamed: 0   Movie    Year Certificate  \
# 4           4  Ra.One  2011.0           U
#
#                                    Genre  \
# 4  Action, Adventure, Sci-Fi
#
#                                             Overview  Runtime  Rating  \
# 4      When the titular antagonist of an action g...      156     4.6
#
#    No.of.Ratings
# 4          37211

# %%
movies.sample(5)
# Out:
#       Unnamed: 0           Movie    Year Certificate  \
# 847          847         Sathyam  2008.0          UA
# 149          149      Prasthanam  2010.0         NaN
# 512          512            Guru  1980.0           U
# 878          878      Malliswari  1951.0           U
# 1013        1013  Soggadi Pellam  1996.0           U
#
#                                     Genre  \
# 847             Action, Drama
# 149             Action, Drama
# 512      Action, Crime, Drama
# 878   Drama, History, Musical
# 1013                    Drama
#
#                                                Overview  Runtime  Rating  \
# 847       Sathyam, an assistant police commissioner,...      137     5.1
# 149       A politician's hot-blooded son starts to r...      153     8.3
# 512       A rich philanthropist has a secret occupat...      159     6.5
# 878       Nagaraju and Malliswari want to get marrie...      194     7.0
# 1013                                                NaN      141     4.1
#
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1400 non-null   int64
#  1   Movie          1400 non-null   object
#  2   Year           1352 non-null   float64
#  3   Certificate    951 non-null    object
#  4   Genre          1389 non-null   object
#  5   Overview       1221 non-null   object
#  6   Runtime        1400 non-null   int64
#  7   Rating         1400 non-null   float64
#  8   No.of.Ratings  1400 non-null   int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 98.6+ KB

# %%
movies.describe(  )
# Out:
#        Unnamed: 0         Year      Runtime       Rating  No.of.Ratings
# count   1400.0000  1352.000000  1400.000000  1400.000000    1400.000000
# mean     699.5000  2005.013314   121.764286     6.317214    1214.755714
# std      404.2895    13.148859    55.925792     1.314660    4328.073152
# min        0.0000  1932.000000     0.000000     1.000000      49.000000
# 25%      349.7500  1997.000000   123.000000     5.500000      92.000000
# 50%      699.5000  2009.000000   141.000000     6.500000     255.500000
# 75%     1049.2500  2015.000000   154.000000     7.300000     829.000000
# max     1399.0000  2020.000000   300.000000     9.500000   99114.000000

# %%
movies.isnull()
# Out:
#       Unnamed: 0  Movie   Year  Certificate  Genre  Overview  Runtime  Rating  \
# 0          False  False  False        False  False     False    False   False
# 1          False  False  False        False  False     False    False   False
# 2          False  False  False        False  False     False    False   False
# 3          False  False  False        False  False     False    False   False
# 4          False  False  False        False  False     False    False   False
# ...          ...    ...    ...          ...    ...       ...      ...     ...
# 1395       False  False  False         True   True      True    False   False
# 1396       False  False  False         True  False     False    False   False
# 1397       False  False  False         True  False     False    False   False
# 1398       False  False  False        False   True     False    False   False
# 1399       False  False  False        False  False     False    False   False
#
#       No.of.Ratings
# ...

# %%
movies.isnull().sum()
# Out:
# Unnamed: 0         0
# Movie              0
# Year              48
# Certificate      449
# Genre             11
# Overview         179
# Runtime            0
# Rating             0
# No.of.Ratings      0
# dtype: int64

# %%
movies.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1395    False
# 1396    False
# 1397    False
# 1398    False
# 1399    False
# Length: 1400, dtype: bool

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies
# Out:
#       Unnamed: 0                        Movie    Year Certificate  \
# 0              0      Bahubali: The Beginning  2015.0          UA
# 1              1  Baahubali 2: The Conclusion  2017.0          UA
# 2              2              1 - Nenokkadine  2014.0          UA
# 3              3                      Dhoom:3  2013.0          UA
# 4              4                       Ra.One  2011.0           U
# ...          ...                          ...     ...         ...
# 1395        1395                Maro Monagadu  1985.0         NaN
# 1396        1396                     Jakkanna  2016.0         NaN
# 1397        1397               Muvva Gopaludu  1987.0         NaN
# 1398        1398        Ninney Ishta Paddaanu  2003.0           U
# 1399        1399                     9 Nelalu  2001.0           U
#
#                                       Genre  \
# 0                 Action, Drama
# 1                 Action, Drama
# 2              Action, Thriller
# ...

# %%
movies['Movie']
# Out:
# 0           Bahubali: The Beginning
# 1       Baahubali 2: The Conclusion
# 2                   1 - Nenokkadine
# 3                           Dhoom:3
# 4                            Ra.One
#                    ...
# 1395                  Maro Monagadu
# 1396                       Jakkanna
# 1397                 Muvva Gopaludu
# 1398          Ninney Ishta Paddaanu
# 1399                       9 Nelalu
# Name: Movie, Length: 1400, dtype: object

# %%
movies[['Movie','Rating']]
# Out:
#                             Movie  Rating
# 0         Bahubali: The Beginning     8.1
# 1     Baahubali 2: The Conclusion     8.2
# 2                 1 - Nenokkadine     8.1
# 3                         Dhoom:3     5.4
# 4                          Ra.One     4.6
# ...                           ...     ...
# 1395                Maro Monagadu     8.6
# 1396                     Jakkanna     6.3
# 1397               Muvva Gopaludu     7.8
# 1398        Ninney Ishta Paddaanu     5.9
# 1399                     9 Nelalu     7.3
#
# [1400 rows x 2 columns]

# %%
movies.iloc[0]
# Out:
# Unnamed: 0                                                       0
# Movie                                      Bahubali: The Beginning
# Year                                                        2015.0
# Certificate                                                     UA
# Genre                                    Action, Drama
# Overview             In ancient India, an adventurous and darin...
# Runtime                                                        159
# Rating                                                         8.1
# No.of.Ratings                                                99114
# Name: 0, dtype: object

# %%
movies.iloc[0:5]
# Out:
#    Unnamed: 0                        Movie    Year Certificate  \
# 0           0      Bahubali: The Beginning  2015.0          UA
# 1           1  Baahubali 2: The Conclusion  2017.0          UA
# 2           2              1 - Nenokkadine  2014.0          UA
# 3           3                      Dhoom:3  2013.0          UA
# 4           4                       Ra.One  2011.0           U
#
#                                    Genre  \
# 0              Action, Drama
# 1              Action, Drama
# 2           Action, Thriller
# 3           Action, Thriller
# 4  Action, Adventure, Sci-Fi
#
#                                             Overview  Runtime  Rating  \
# 0      In ancient India, an adventurous and darin...      159     8.1
# 1      When Shiva, the son of Bahubali, learns ab...      167     8.2
# 2      A rock star must overcome his psychologica...      170     8.1
# 3      When Sahir, a circus entertainer trained i...      172     5.4
# ...

# %%
type(movies.iloc[0])
# Out:
# pandas.core.series.Series

# %%
type(movies.iloc[0:5 ])
# Out:
# pandas.core.frame.DataFrame

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-58-1903381819.py in <cell line: 0>()
# ----> 1 movies[["Movie"]].loc["Bahubali: The Beginning"]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1429         # fall thru to straight lookup
#    1430         self._validate_key(key, axis)
# -> 1431         return self._get_label(key, axis=axis)
#    1432
# ...

# %%
movies.iloc[0:len(movies)]
# Out:
#       Unnamed: 0                        Movie    Year Certificate  \
# 0              0      Bahubali: The Beginning  2015.0          UA
# 1              1  Baahubali 2: The Conclusion  2017.0          UA
# 2              2              1 - Nenokkadine  2014.0          UA
# 3              3                      Dhoom:3  2013.0          UA
# 4              4                       Ra.One  2011.0           U
# ...          ...                          ...     ...         ...
# 1395        1395                Maro Monagadu  1985.0         NaN
# 1396        1396                     Jakkanna  2016.0         NaN
# 1397        1397               Muvva Gopaludu  1987.0         NaN
# 1398        1398        Ninney Ishta Paddaanu  2003.0           U
# 1399        1399                     9 Nelalu  2001.0           U
#
#                                       Genre  \
# 0                 Action, Drama
# 1                 Action, Drama
# 2              Action, Thriller
# ...

# %%
movies.iloc[0:3,0:3]
# Out:
#    Unnamed: 0                        Movie    Year
# 0           0      Bahubali: The Beginning  2015.0
# 1           1  Baahubali 2: The Conclusion  2017.0
# 2           2              1 - Nenokkadine  2014.0

# %%
# Out:
#       Unnamed: 0                        Movie    Year Certificate  \
# 0              0      Bahubali: The Beginning  2015.0          UA
# 1              1  Baahubali 2: The Conclusion  2017.0          UA
# 2              2              1 - Nenokkadine  2014.0          UA
# 3              3                      Dhoom:3  2013.0          UA
# 4              4                       Ra.One  2011.0           U
# ...          ...                          ...     ...         ...
# 1395        1395                Maro Monagadu  1985.0         NaN
# 1396        1396                     Jakkanna  2016.0         NaN
# 1397        1397               Muvva Gopaludu  1987.0         NaN
# 1398        1398        Ninney Ishta Paddaanu  2003.0           U
# 1399        1399                     9 Nelalu  2001.0           U
#
#                                       Genre  \
# 0                 Action, Drama
# 1                 Action, Drama
# 2              Action, Thriller
# ...

# %%
movies.loc[0:3,"Movie"]
# Out:
# 0        Bahubali: The Beginning
# 1    Baahubali 2: The Conclusion
# 2                1 - Nenokkadine
# 3                        Dhoom:3
# Name: Movie, dtype: object

# %%
mask1=movies['Rating']>8
mask2=movies['No.of.Ratings']>1000
movies[mask1 & mask2]
# Out:
#      Unnamed: 0                        Movie    Year Certificate  \
# 0             0      Bahubali: The Beginning  2015.0          UA
# 1             1  Baahubali 2: The Conclusion  2017.0          UA
# 2             2              1 - Nenokkadine  2014.0          UA
# 8             8                  Arjun Reddy  2017.0           A
# 9             9                 Rangasthalam  2018.0          UA
# 18           18                       Athadu  2005.0           U
# 31           31                     Mahanati  2018.0           U
# 39           39                   Bommarillu  2006.0           U
# 50           50                        Vedam  2010.0           A
# 54           54                       Jersey  2019.0           U
# 65           65               Pelli Choopulu  2016.0          UA
# 72           72  Agent Sai Srinivasa Athreya  2019.0          UA
# 83           83                      Kshanam  2016.0         NaN
# ...

# %%
movies=movies.dropna()
mask1=movies['Genre'].str.split(",").apply(lambda x :any(item.strip().lower()=="comedy" for item in x))
mask2 =movies["Rating"]>8
movies[mask1 & mask2].sort_values("Rating",ascending=False).iloc[0]["Movie"]
# Out:
# 'Maya Bazaar'
