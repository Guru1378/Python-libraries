# %% [markdown]
# <a href="https://colab.research.google.com/github/Guru1378/Python-libraries/blob/main/Pandas_Merging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data1=pd.read_csv("deliveries.csv")

# %%
data2=pd.read_csv("matches.csv")

# %%
data1
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
data=data1[["match_id","batting_team"]]

# %%
data
# Out:
#         match_id           batting_team
# 0         335982  Kolkata Knight Riders
# 1         335982  Kolkata Knight Riders
# 2         335982  Kolkata Knight Riders
# 3         335982  Kolkata Knight Riders
# 4         335982  Kolkata Knight Riders
# ...          ...                    ...
# 260915   1426312  Kolkata Knight Riders
# 260916   1426312  Kolkata Knight Riders
# 260917   1426312  Kolkata Knight Riders
# 260918   1426312  Kolkata Knight Riders
# 260919   1426312  Kolkata Knight Riders
#
# [260920 rows x 2 columns]

# %%
data2
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
dataa=data2[["city","winner"]]

# %%
dataa
# Out:
#             city                       winner
# 0      Bangalore        Kolkata Knight Riders
# 1     Chandigarh          Chennai Super Kings
# 2          Delhi             Delhi Daredevils
# 3         Mumbai  Royal Challengers Bangalore
# 4        Kolkata        Kolkata Knight Riders
# ...          ...                          ...
# 1090   Hyderabad          Sunrisers Hyderabad
# 1091   Ahmedabad        Kolkata Knight Riders
# 1092   Ahmedabad             Rajasthan Royals
# 1093     Chennai          Sunrisers Hyderabad
# 1094     Chennai        Kolkata Knight Riders
#
# [1095 rows x 2 columns]

# %%
new_data=pd.concat([data,dataa],ignore_index=True)

# %%
# Out:
#         match_id           batting_team       city                 winner
# 0       335982.0  Kolkata Knight Riders        NaN                    NaN
# 1       335982.0  Kolkata Knight Riders        NaN                    NaN
# 2       335982.0  Kolkata Knight Riders        NaN                    NaN
# 3       335982.0  Kolkata Knight Riders        NaN                    NaN
# 4       335982.0  Kolkata Knight Riders        NaN                    NaN
# ...          ...                    ...        ...                    ...
# 262010       NaN                    NaN  Hyderabad    Sunrisers Hyderabad
# 262011       NaN                    NaN  Ahmedabad  Kolkata Knight Riders
# 262012       NaN                    NaN  Ahmedabad       Rajasthan Royals
# 262013       NaN                    NaN    Chennai    Sunrisers Hyderabad
# 262014       NaN                    NaN    Chennai  Kolkata Knight Riders
#
# [262015 rows x 4 columns]

# %%
multi=pd.concat([data,dataa],keys=["data","dataa"])

# %%
multi
# Out:
#             match_id           batting_team       city                 winner
# data  0     335982.0  Kolkata Knight Riders        NaN                    NaN
#       1     335982.0  Kolkata Knight Riders        NaN                    NaN
#       2     335982.0  Kolkata Knight Riders        NaN                    NaN
#       3     335982.0  Kolkata Knight Riders        NaN                    NaN
#       4     335982.0  Kolkata Knight Riders        NaN                    NaN
# ...              ...                    ...        ...                    ...
# dataa 1090       NaN                    NaN  Hyderabad    Sunrisers Hyderabad
#       1091       NaN                    NaN  Ahmedabad  Kolkata Knight Riders
#       1092       NaN                    NaN  Ahmedabad       Rajasthan Royals
#       1093       NaN                    NaN    Chennai    Sunrisers Hyderabad
#       1094       NaN                    NaN    Chennai  Kolkata Knight Riders
#
# [262015 rows x 4 columns]

# %%
multi.loc[("data",2)]
# Out:
# match_id                     335982.0
# batting_team    Kolkata Knight Riders
# city                              NaN
# winner                            NaN
# Name: (data, 2), dtype: object

# %%
pd.concat([data,dataa],axis=1).dropna()
# Out:
#       match_id           batting_team        city                       winner
# 0       335982  Kolkata Knight Riders   Bangalore        Kolkata Knight Riders
# 1       335982  Kolkata Knight Riders  Chandigarh          Chennai Super Kings
# 2       335982  Kolkata Knight Riders       Delhi             Delhi Daredevils
# 3       335982  Kolkata Knight Riders      Mumbai  Royal Challengers Bangalore
# 4       335982  Kolkata Knight Riders     Kolkata        Kolkata Knight Riders
# ...        ...                    ...         ...                          ...
# 1090    335986  Kolkata Knight Riders   Hyderabad          Sunrisers Hyderabad
# 1091    335986  Kolkata Knight Riders   Ahmedabad        Kolkata Knight Riders
# 1092    335986  Kolkata Knight Riders   Ahmedabad             Rajasthan Royals
# 1093    335986  Kolkata Knight Riders     Chennai          Sunrisers Hyderabad
# 1094    335986  Kolkata Knight Riders     Chennai        Kolkata Knight Riders
#
# [1039 rows x 4 columns]

# %%
data1=pd.read_csv("deliveries.csv")
data1
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
data2=pd.read_csv("matches.csv")
data2.rename(columns={"id":"match_id"},inplace=True)

# %%
new_data=data1.merge(data2,how="inner",on="match_id")
new_data
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
new_data1=data1.merge(data2,how="left",on="match_id")

# %%
new_data1
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
new_data2=data1.merge(data2,how="right",on="match_id")

# %%
new_data2
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
new_data1==new_data2
# Out:
#         match_id  inning  batting_team  bowling_team  over  ball  batter  \
# 0           True    True          True          True  True  True    True
# 1           True    True          True          True  True  True    True
# 2           True    True          True          True  True  True    True
# 3           True    True          True          True  True  True    True
# 4           True    True          True          True  True  True    True
# ...          ...     ...           ...           ...   ...   ...     ...
# 260915      True    True          True          True  True  True    True
# 260916      True    True          True          True  True  True    True
# 260917      True    True          True          True  True  True    True
# 260918      True    True          True          True  True  True    True
# 260919      True    True          True          True  True  True    True
#
#         bowler  non_striker  batsman_runs  ...  toss_decision  winner  result  \
# ...

# %%
new_data = data.merge(data2,how="outer",on="match_id")

# %%
new_data
# Out:
#         match_id           batting_team   season       city        date  \
# 0         335982  Kolkata Knight Riders  2007/08  Bangalore  2008-04-18
# 1         335982  Kolkata Knight Riders  2007/08  Bangalore  2008-04-18
# 2         335982  Kolkata Knight Riders  2007/08  Bangalore  2008-04-18
# 3         335982  Kolkata Knight Riders  2007/08  Bangalore  2008-04-18
# 4         335982  Kolkata Knight Riders  2007/08  Bangalore  2008-04-18
# ...          ...                    ...      ...        ...         ...
# 260915   1426312  Kolkata Knight Riders     2024    Chennai  2024-05-26
# 260916   1426312  Kolkata Knight Riders     2024    Chennai  2024-05-26
# 260917   1426312  Kolkata Knight Riders     2024    Chennai  2024-05-26
# 260918   1426312  Kolkata Knight Riders     2024    Chennai  2024-05-26
# 260919   1426312  Kolkata Knight Riders     2024    Chennai  2024-05-26
#
#        match_type player_of_match                                     venue  \
# ...

# %%
new_data1
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
new_data2
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
new_data
# Out:
#         match_id           batting_team   season       city        date  \
# 0         335982  Kolkata Knight Riders  2007/08  Bangalore  2008-04-18
# 1         335982  Kolkata Knight Riders  2007/08  Bangalore  2008-04-18
# 2         335982  Kolkata Knight Riders  2007/08  Bangalore  2008-04-18
# 3         335982  Kolkata Knight Riders  2007/08  Bangalore  2008-04-18
# 4         335982  Kolkata Knight Riders  2007/08  Bangalore  2008-04-18
# ...          ...                    ...      ...        ...         ...
# 260915   1426312  Kolkata Knight Riders     2024    Chennai  2024-05-26
# 260916   1426312  Kolkata Knight Riders     2024    Chennai  2024-05-26
# 260917   1426312  Kolkata Knight Riders     2024    Chennai  2024-05-26
# 260918   1426312  Kolkata Knight Riders     2024    Chennai  2024-05-26
# 260919   1426312  Kolkata Knight Riders     2024    Chennai  2024-05-26
#
#        match_type player_of_match                                     venue  \
# ...

# %%
new_data.columns
# Out:
# Index(['match_id', 'batting_team', 'season', 'city', 'date', 'match_type',
#        'player_of_match', 'venue', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'winner', 'result', 'result_margin', 'target_runs',
#        'target_overs', 'super_over', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
new_data[(new_data["batting_team"]=="Chennai Super Kings") & (new_data["winner"]=="Chennai Super Kings")].shape
# Out:
# (16507, 21)

# %%
new_data[(new_data["batting_team"]=="Kolkata Knight Riders") & (new_data["winner"]=="Chennai Super Kings")].shape
# Out:
# (2340, 21)

# %%
import numpy as np

# %%
np.intersect1d(data["match_id"],data2["match_id"])
# Out:
# array([ 335982,  335983,  335984, ..., 1426310, 1426311, 1426312])

# %%
np.setdiff1d(data["match_id"],data2["match_id"])
# Out:
# array([], dtype=int64)

# %%
np.intersect1d(data["match_id"],data2["match_id"]).shape
# Out:
# (1095,)

# %%
np.setdiff1d(data["match_id"],data2["match_id"]).shape
# Out:
# (0,)
