# %% [markdown]
# <a href="https://colab.research.google.com/github/Guru1378/Python-libraries/blob/main/String_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
a=np.array([1,2,3,4,5])

# %%
a*5
# Out:
# array([ 5, 10, 15, 20, 25])

# %%
listt=["Guru","Prasad"]
[i.startswith("G") for i in listt]
# Out:
# [True, False]

# %%
listt=["Guru","Prasad",None,"Nooliveedu"]
[i.startswith("G") for i in listt]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-6-1444502633.py in <cell line: 0>()
#       1 listt=["Guru","Prasad",None,"Nooliveedu"]
# ----> 2 [i.startswith("G") for i in listt]
#
# /tmp/ipython-input-6-1444502633.py in <listcomp>(.0)
#       1 listt=["Guru","Prasad",None,"Nooliveedu"]
# ----> 2 [i.startswith("G") for i in listt]
#
# AttributeError: 'NoneType' object has no attribute 'startswith'

# %%
listt=pd.Series(["Guru","Prasad","Nooliveedu",None])

# %%
listt.str.startswith("G")
# Out:
# 0     True
# 1    False
# 2    False
# 3     None
# dtype: object

# %%
data=pd.read_csv("Titanic-Dataset.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
new_data=data[(data["Sex"]=="male")&(data["Survived"]==1)][["PassengerId","Name","Age"]]

# %%
new_data
# Out:
#      PassengerId                             Name   Age
# 17            18     Williams, Mr. Charles Eugene   NaN
# 21            22            Beesley, Mr. Lawrence  34.0
# 23            24     Sloper, Mr. William Thompson  28.0
# 36            37                 Mamee, Mr. Hanna   NaN
# 55            56                Woolner, Mr. Hugh   NaN
# ..           ...                              ...   ...
# 838          839                  Chip, Mr. Chang  32.0
# 839          840             Marechal, Mr. Pierre   NaN
# 857          858           Daly, Mr. Peter Denis   51.0
# 869          870  Johnson, Master. Harold Theodor   4.0
# 889          890            Behr, Mr. Karl Howell  26.0
#
# [109 rows x 3 columns]

# %%
dataa=new_data.fillna(0).sort_values("Age",ascending=False).iloc[[0]].Name

# %%
dataa
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
data=pd.read_csv("Titanic-Dataset.csv")

# %%
data["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
new_data=data["Name"].tolist()

# %%
new_data=data["Name"]

# %%
new_data
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
data["Name"].str.lower()
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
dataa=data["Name"].str.upper()

# %%
dataa
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %%
dataa.str.len().max()
# Out:
# 82

# %%
data=pd.read_csv("Titanic-Dataset.csv")

# %%
data["lastname"]=data["Name"].str.split(",").str.get(0)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# 3             Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                              Mr. William Henry    male  35.0      0      0
# ...

# %%
data["Name"].str[::-1]
# Out:
# 0                                 sirraH newO .rM
# 1      )reyahT sggirB ecnerolF( yeldarB nhoJ .srM
# 2                                     aniaL .ssiM
# 3              )leeP yaM yliL( htaeH seuqcaJ .srM
# 4                               yrneH mailliW .rM
#                           ...
# 886                                   sazouJ .veR
# 887                          htidE teragraM .ssiM
# 888                "eirraC" neleH enirehtaC .ssiM
# 889                               llewoH lraK .rM
# 890                                   kcirtaP .rM
# Name: Name, Length: 891, dtype: object

# %%
data["Name"].str[::2]
# Out:
# 0                     r wnHri
# 1       r.Jh rde Foec rgsTae)
# 2                       is an
# 3           r.JcusHah(iyMyPe)
# 4                    r ila er
#                 ...
# 886                     e.Joa
# 887                is agrtEih
# 888           is ahrn ee Cri"
# 889                   r alHwl
# 890                     r arc
# Name: Name, Length: 891, dtype: object

# %%
data["Name"]
# Out:
# 0                                  Mr. Owen Harris
# 1       Mrs. John Bradley (Florence Briggs Thayer)
# 2                                      Miss. Laina
# 3               Mrs. Jacques Heath (Lily May Peel)
# 4                                Mr. William Henry
#                           ...
# 886                                    Rev. Juozas
# 887                           Miss. Margaret Edith
# 888                 Miss. Catherine Helen "Carrie"
# 889                                Mr. Karl Howell
# 890                                    Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# 3             Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                              Mr. William Henry    male  35.0      0      0
# ...

# %%
new_data=data.sort_values(by="Age",ascending=False).iloc[0].PassengerId

# %%
new_data
# Out:
# np.int64(631)

# %%
age=int(new_data)

# %%
age
# Out:
# 631
